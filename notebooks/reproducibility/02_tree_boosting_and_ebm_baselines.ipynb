# %% [markdown]
# # 02. Tree, Boosting, and EBM Baselines
#
# Runs Random Forest, HistGradientBoosting, XGBoost, LightGBM, CatBoost, and EBM directly with fold-level records and training-fold-only inner validation.
#
# ## Paper table targets
#
# - Tables 7-10: modern tabular-baseline rows in the four dataset performance tables
# - Table A8: supplemental tabular-baseline full-metric summary
#
# This notebook does not import legacy result tables or emit hard-coded numeric rows. It runs the direct experiment backend and then displays CSV files generated in the same output tree.

# %%
from pathlib import Path
import subprocess
import sys
import pandas as pd


def find_project_root(start: Path) -> Path:
    start = start.resolve()
    for path in [start, *start.parents]:
        if (path / "experiments" / "reproducible_paper_tables.py").exists():
            return path
    raise RuntimeError("Could not find project root")

PROJECT_ROOT = find_project_root(Path.cwd())
OUTPUT_ROOT = PROJECT_ROOT / "output" / "reproducible_paper_tables"
PYTHON = PROJECT_ROOT / "scripts" / "python_with_local_deps.sh"
RUN_DIRECT_EXPERIMENTS = True
DATASETS = ["Breast_Cancer_Wisconsin_(Original)", "Vowel", "Spambase", "Gisette"]
print(f"PROJECT_ROOT={PROJECT_ROOT}")
print(f"OUTPUT_ROOT={OUTPUT_ROOT}")
# Out:
# PROJECT_ROOT=/home/harp3133t/Research/03_Research/GRS-ANFIS_E512
# OUTPUT_ROOT=/home/harp3133t/Research/03_Research/GRS-ANFIS_E512/output/reproducible_paper_tables

# %%
cmd = [str(PYTHON), "experiments/reproducible_paper_tables.py", "--task", "tabular-baselines", "--output-root", str(OUTPUT_ROOT)]
cmd += ["--datasets", *DATASETS]
cmd += []
print(" ".join(cmd))
if RUN_DIRECT_EXPERIMENTS:
    subprocess.run(cmd, cwd=PROJECT_ROOT, check=True)
else:
    print("RUN_DIRECT_EXPERIMENTS=False: command not executed")
# Out:
# /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/scripts/python_with_local_deps.sh experiments/reproducible_paper_tables.py --task tabular-baselines --output-root /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/output/reproducible_paper_tables --datasets Breast_Cancer_Wisconsin_(Original) Vowel Spambase Gisette
# /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/.deps/torch/cuda/__init__.py:180: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# [LightGBM] [Fatal] Do not support special JSON characters in feature name.
# Loading /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/data/gisette_train.data...
# Loading /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/data/gisette_train.labels...
# [tabular-baselines] complete in 5190.9s; output_root=/home/harp3133t/Research/03_Research/GRS-ANFIS_E512/output/reproducible_paper_tables

# %%
for rel in ['02_tabular_baseline_folds.csv',
    '02_tabular_baseline_summary.csv',
    '02_tabular_baseline_skipped.csv']:
    path = OUTPUT_ROOT / rel
    print(f"\n=== {rel} ===")
    if path.exists():
        display(pd.read_csv(path).head(20))
    else:
        print(f"missing: {path}")
# Out:
# === 02_tabular_baseline_folds.csv ===
#                                dataset display_dataset  fold         model  \
# 0   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     1  RandomForest
# 1   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     1           HGB
# 2   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     1       XGBoost
# 3   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     1      LightGBM
# 4   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     1      CatBoost
# 5   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     1           EBM
# 6   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     2  RandomForest
# 7   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     2           HGB
# 8   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     2       XGBoost
# 9   Breast_Cancer_Wisconsin_(Original)   Breast Cancer     2      LightGBM
# 10  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     2      CatBoost
# 11  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     2           EBM
# 12  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     3  RandomForest
# 13  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     3           HGB
# 14  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     3       XGBoost
# 15  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     3      LightGBM
# 16  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     3      CatBoost
# 17  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     3           EBM
# 18  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     4  RandomForest
# 19  Breast_Cancer_Wisconsin_(Original)   Breast Cancer     4           HGB
#
#     input_dim  inner_f1                                   best_params_json  \
# 0          80  0.938272      {"max_features": "sqrt", "n_estimators": 300}
# 1          80  0.936709  {"l2_regularization": 0.0, "learning_rate": 0....
# 2          80  0.936709  {"colsample_bytree": 0.8, "learning_rate": 0.0...
# 3          80  0.950000  {"colsample_bytree": 0.9, "learning_rate": 0.0...
# 4          80  0.936709  {"depth": 3, "iterations": 500, "l2_leaf_reg":...
# 5          80  0.911392  {"early_stopping_rounds": 50, "interactions": ...
# 6          80  0.962963      {"max_features": "sqrt", "n_estimators": 300}
# 7          80  0.938272  {"l2_regularization": 0.1, "learning_rate": 0....
# 8          80  0.925000  {"colsample_bytree": 0.9, "learning_rate": 0.0...
# 9          80  0.951220  {"colsample_bytree": 0.9, "learning_rate": 0.0...
# 10         80  0.951220  {"depth": 4, "iterations": 300, "l2_leaf_reg":...
# 11         80  0.938272  {"early_stopping_rounds": 50, "interactions": ...
# 12         80  0.923077      {"max_features": "sqrt", "n_estimators": 300}
# 13         80  0.909091  {"l2_regularization": 0.0, "learning_rate": 0....
# 14         80  0.894737  {"colsample_bytree": 0.8, "learning_rate": 0.0...
# 15         80  0.909091  {"colsample_bytree": 0.8, "learning_rate": 0.0...
# 16         80  0.923077  {"depth": 4, "iterations": 300, "l2_leaf_reg":...
# 17         80  0.925000  {"early_stopping_rounds": 50, "interactions": ...
# 18         80  0.947368  {"class_weight": "balanced", "max_features": "...
# 19         80  0.918919  {"l2_regularization": 0.0, "learning_rate": 0....
#
#          acc  precision    recall        f1        source
# 0   0.971429   0.978261  0.937500  0.957447  direct rerun
# 1   0.964286   0.977778  0.916667  0.946237  direct rerun
# 2   0.971429   0.978261  0.937500  0.957447  direct rerun
# 3   0.964286   0.957447  0.937500  0.947368  direct rerun
# 4   0.957143   0.977273  0.895833  0.934783  direct rerun
# 5   0.978571   1.000000  0.937500  0.967742  direct rerun
# 6   0.957143   0.937500  0.937500  0.937500  direct rerun
# 7   0.928571   0.913043  0.875000  0.893617  direct rerun
# 8   0.950000   0.918367  0.937500  0.927835  direct rerun
# 9   0.942857   0.916667  0.916667  0.916667  direct rerun
# 10  0.942857   0.916667  0.916667  0.916667  direct rerun
# 11  0.964286   0.921569  0.979167  0.949495  direct rerun
# 12  0.950000   0.918367  0.937500  0.927835  direct rerun
# 13  0.957143   0.937500  0.937500  0.937500  direct rerun
# 14  0.971429   0.958333  0.958333  0.958333  direct rerun
# 15  0.971429   0.940000  0.979167  0.959184  direct rerun
# 16  0.964286   0.938776  0.958333  0.948454  direct rerun
# 17  0.964286   0.921569  0.979167  0.949495  direct rerun
# 18  0.964286   0.958333  0.938776  0.948454  direct rerun
# 19  0.928571   0.897959  0.897959  0.897959  direct rerun
# === 02_tabular_baseline_summary.csv ===
#                                dataset display_dataset         model  \
# 0   Breast_Cancer_Wisconsin_(Original)   Breast Cancer      CatBoost
# 1   Breast_Cancer_Wisconsin_(Original)   Breast Cancer           EBM
# 2   Breast_Cancer_Wisconsin_(Original)   Breast Cancer           HGB
# 3   Breast_Cancer_Wisconsin_(Original)   Breast Cancer      LightGBM
# 4   Breast_Cancer_Wisconsin_(Original)   Breast Cancer  RandomForest
# 5   Breast_Cancer_Wisconsin_(Original)   Breast Cancer       XGBoost
# 6                              Gisette         Gisette      CatBoost
# 7                              Gisette         Gisette           EBM
# 8                              Gisette         Gisette           HGB
# 9                              Gisette         Gisette      LightGBM
# 10                             Gisette         Gisette  RandomForest
# 11                             Gisette         Gisette       XGBoost
# 12                            Spambase        Spambase      CatBoost
# 13                            Spambase        Spambase           EBM
# 14                            Spambase        Spambase           HGB
# 15                            Spambase        Spambase  RandomForest
# 16                               Vowel           Vowel      CatBoost
# 17                               Vowel           Vowel           EBM
# 18                               Vowel           Vowel           HGB
# 19                               Vowel           Vowel      LightGBM
#
#     fold_mean  fold_std  input_dim_mean  input_dim_std  inner_f1_mean  \
# 0         3.0  1.581139            80.0            0.0       0.936390
# 1         3.0  1.581139            80.0            0.0       0.926685
# 2         3.0  1.581139            80.0            0.0       0.925598
# 3         3.0  1.581139            80.0            0.0       0.922259
# 4         3.0  1.581139            80.0            0.0       0.939336
# 5         3.0  1.581139            80.0            0.0       0.924932
# 6         3.0  1.581139          5000.0            0.0       0.972960
# 7         3.0  1.581139          5000.0            0.0       0.974219
# 8         3.0  1.581139          5000.0            0.0       0.979599
# 9         3.0  1.581139          5000.0            0.0       0.982315
# 10        3.0  1.581139          5000.0            0.0       0.971445
# 11        3.0  1.581139          5000.0            0.0       0.978195
# 12        3.0  1.581139            57.0            0.0       0.948426
# 13        3.0  1.581139            57.0            0.0       0.947218
# 14        3.0  1.581139            57.0            0.0       0.953586
# 15        3.0  1.581139            57.0            0.0       0.946362
# 16        3.0  1.581139            29.0            0.0       0.876217
# 17        3.0  1.581139            29.0            0.0       0.896533
# 18        3.0  1.581139            29.0            0.0       0.925673
# 19        3.0  1.581139            29.0            0.0       0.941955
#
#     inner_f1_std  acc_mean   acc_std  precision_mean  precision_std  \
# 0       0.012433  0.959949  0.010808        0.949869       0.023025
# 1       0.016067  0.967081  0.008239        0.951872       0.035639
# 2       0.012263  0.941326  0.017880        0.935732       0.031582
# 3       0.026820  0.957081  0.011295        0.945431       0.017658
# 4       0.016536  0.961377  0.008122        0.949982       0.022806
# 5       0.017553  0.954193  0.016575        0.948770       0.023291
# 6       0.002107  0.972500  0.006095        0.972089       0.009498
# 7       0.004671  0.973833  0.004951        0.973737       0.008369
# 8       0.002717  0.976000  0.005572        0.976361       0.008281
# 9       0.003972  0.979000  0.003745        0.979344       0.006052
# 10      0.002393  0.972167  0.006578        0.983018       0.010335
# 11      0.003260  0.975667  0.006078        0.976665       0.008539
# 12      0.007163  0.951099  0.005686        0.946654       0.007120
# 13      0.011937  0.950882  0.006832        0.942637       0.006441
# 14      0.006252  0.956314  0.007304        0.943964       0.007621
# 15      0.005180  0.951966  0.004585        0.950913       0.010169
# 16      0.015484  0.907071  0.018069        0.909670       0.018734
# 17      0.024123  0.909091  0.021128        0.911724       0.020869
# 18      0.009201  0.933333  0.027984        0.937028       0.027839
# 19      0.015727  0.947475  0.021605        0.949927       0.021907
#
#     recall_mean  recall_std   f1_mean    f1_std
# 0      0.933503    0.027361  0.941291  0.016257
# 1      0.954422    0.022595  0.952513  0.011285
# 2      0.892092    0.040140  0.912840  0.026870
# 3      0.929592    0.031044  0.937141  0.016791
# 4      0.937755    0.000570  0.943721  0.011349
# 5      0.917177    0.038305  0.932347  0.024891
# 6      0.973000    0.004314  0.972529  0.005979
# 7      0.974000    0.005603  0.973846  0.004871
# 8      0.975667    0.004503  0.976002  0.005505
# 9      0.978667    0.001826  0.979000  0.003686
# 10     0.961000    0.003456  0.971871  0.006517
# 11     0.974667    0.005821  0.975650  0.006023
# 12     0.928286    0.016607  0.937290  0.007859
# 13     0.932143    0.020187  0.937242  0.009384
# 14     0.945371    0.022774  0.944505  0.010018
# 15     0.926073    0.015261  0.938216  0.006316
# 16     0.907071    0.018069  0.906295  0.018266
# 17     0.909091    0.021128  0.907835  0.021802
# 18     0.933333    0.027984  0.932723  0.028143
# 19     0.947475    0.021605  0.947197  0.021631
# === 02_tabular_baseline_skipped.csv ===
#     dataset  fold     model                                             reason
# 0  Spambase     1   XGBoost  ValueError('feature_names must be string, and ...
# 1  Spambase     1  LightGBM  LightGBMError('Do not support special JSON cha...
# 2  Spambase     2   XGBoost  ValueError('feature_names must be string, and ...
# 3  Spambase     2  LightGBM  LightGBMError('Do not support special JSON cha...
# 4  Spambase     3   XGBoost  ValueError('feature_names must be string, and ...
# 5  Spambase     3  LightGBM  LightGBMError('Do not support special JSON cha...
# 6  Spambase     4   XGBoost  ValueError('feature_names must be string, and ...
# 7  Spambase     4  LightGBM  LightGBMError('Do not support special JSON cha...
# 8  Spambase     5   XGBoost  ValueError('feature_names must be string, and ...
# 9  Spambase     5  LightGBM  LightGBMError('Do not support special JSON cha...
