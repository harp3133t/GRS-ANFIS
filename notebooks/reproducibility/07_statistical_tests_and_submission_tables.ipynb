# %% [markdown]
# # 07. Statistical Tests and Submission Table Inventory
#
# Builds the final inventory from generated direct-experiment CSVs and writes the notebook-to-paper table map.
#
# ## Paper table targets
#
# - Table A9: paired statistics for selected comparisons
# - Final generated table inventory
#
# This notebook does not import legacy result tables or emit hard-coded numeric rows. It runs the direct experiment backend and then displays CSV files generated in the same output tree.

# %%
from pathlib import Path
import subprocess
import sys
import pandas as pd


def find_project_root(start: Path) -> Path:
    start = start.resolve()
    for path in [start, *start.parents]:
        if (path / "experiments" / "reproducible_paper_tables.py").exists():
            return path
    raise RuntimeError("Could not find project root")

PROJECT_ROOT = find_project_root(Path.cwd())
OUTPUT_ROOT = PROJECT_ROOT / "output" / "reproducible_paper_tables"
PYTHON = PROJECT_ROOT / "scripts" / "python_with_local_deps.sh"
RUN_DIRECT_EXPERIMENTS = True
DATASETS = ["Breast_Cancer_Wisconsin_(Original)", "Vowel", "Spambase", "Gisette"]
print(f"PROJECT_ROOT={PROJECT_ROOT}")
print(f"OUTPUT_ROOT={OUTPUT_ROOT}")
# Out:
# PROJECT_ROOT=/home/harp3133t/Research/03_Research/GRS-ANFIS_E512
# OUTPUT_ROOT=/home/harp3133t/Research/03_Research/GRS-ANFIS_E512/output/reproducible_paper_tables

# %%
cmd = [str(PYTHON), "experiments/reproducible_paper_tables.py", "--task", "inventory", "--output-root", str(OUTPUT_ROOT)]
cmd += ["--datasets", *DATASETS]
cmd += []
print(" ".join(cmd))
if RUN_DIRECT_EXPERIMENTS:
    subprocess.run(cmd, cwd=PROJECT_ROOT, check=True)
else:
    print("RUN_DIRECT_EXPERIMENTS=False: command not executed")
# Out:
# /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/scripts/python_with_local_deps.sh experiments/reproducible_paper_tables.py --task inventory --output-root /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/output/reproducible_paper_tables --datasets Breast_Cancer_Wisconsin_(Original) Vowel Spambase Gisette
# /home/harp3133t/Research/03_Research/GRS-ANFIS_E512/.deps/torch/cuda/__init__.py:180: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# [inventory] complete in 0.0s; output_root=/home/harp3133t/Research/03_Research/GRS-ANFIS_E512/output/reproducible_paper_tables

# %%
for rel in ['07_generated_table_inventory.csv',
    'paper_table_map.csv']:
    path = OUTPUT_ROOT / rel
    print(f"\n=== {rel} ===")
    if path.exists():
        display(pd.read_csv(path).head(20))
    else:
        print(f"missing: {path}")
# Out:
# === 07_generated_table_inventory.csv ===
#                                                  file  rows  columns  \
# 0                   00_common_experiment_settings.csv     5        3
# 1                                   00_data_audit.csv     4        7
# 2                       00_ga_pso_hyperparameters.csv     8        8
# 3           00_ga_pso_selected_feature_resolution.csv     8        7
# 4                    00_grs_anfis_hyperparameters.csv     4       14
# 5                      00_h_anfis_hyperparameters.csv     4        8
# 6                        00_hyperparameter_ranges.csv     5        3
# 7                       01_main_neuro_fuzzy_folds.csv   160       12
# 8                     01_main_neuro_fuzzy_summary.csv    32       19
# 9                       02_tabular_baseline_folds.csv   120       12
# 10                    02_tabular_baseline_skipped.csv     0        4
# 11                    02_tabular_baseline_summary.csv    24       17
# 12                    05_boundary/fold_bin_counts.csv    71       23
# 13                            05_boundary/fold_df.csv    71       23
# 14                    05_boundary/fold_metrics_df.csv    20        8
# 15                   05_boundary/q1_by_dataset_df.csv     4       19
# 16                      05_boundary/q1_overall_df.csv     1       14
# 17              05_boundary/q1_summary_by_dataset.csv     4       19
# 18                 05_boundary/q1_summary_overall.csv     1       14
# 19  06_interpretability/global_explanation_summary...     9        4
#
#                                          column_names
# 0                          item, setting, source_file
# 1   dataset, display_dataset, n_samples, model_inp...
# 2   dataset, model, lr, n_rules, epochs, configure...
# 3   dataset, model, configured_selected_features, ...
# 4   dataset, lr_primary, lr_complementary, primary...
# 5   dataset, lr, epochs, module_rules, top_rules, ...
# 6                 hyperparameter, role, typical_range
# 7   dataset, display_dataset, fold, model, acc, pr...
# 8   dataset, display_dataset, model, fold_mean, fo...
# 9   dataset, display_dataset, fold, model, input_d...
# 10                       dataset, fold, model, reason
# 11  dataset, display_dataset, model, fold_mean, fo...
# 12  dataset, dataset_key, mode, fold, task_kind, s...
# 13  dataset, dataset_key, mode, fold, task_kind, s...
# 14  dataset, fold, status, task_kind, primary_acc,...
# 15  dataset, boundary_bin, n_success_folds, n_fail...
# 16  scope, q1_n_samples, wrong_to_right, right_to_...
# 17  dataset, boundary_bin, n_success_folds, n_fail...
# 18  scope, q1_n_samples, wrong_to_right, right_to_...
# 19       method, feature, normalized_importance, rank
# === paper_table_map.csv ===
#                                             notebook  \
# 0                00_environment_and_data_audit.ipynb
# 1      01_main_neuro_fuzzy_and_svm_experiments.ipynb
# 2           02_tree_boosting_and_ebm_baselines.ipynb
# 3            03_reviewer_table_package_rebuild.ipynb
# 4     04_ablation_robustness_and_htsk_analysis.ipynb
# 5  05_complementary_boundary_and_error_recovery.i...
# 6  06_interpretability_shap_lime_grs_rule_path.ipynb
# 7   07_statistical_tests_and_submission_tables.ipynb
#
#                  paper_table_number_v6  \
# 0                           Tables 1-6
# 1                          Tables 7-10
# 2                Tables 7-10; Table A8
# 3        Tables 1, 7-17, A1-A9 package
# 4           Tables 13-14; Tables A1-A6
# 5               Table 12; Tables 15-17
# 6          Table A7; supports Table 17
# 7  Table A9; generated-table inventory
#
#                           paper_table_title_or_scope  \
# 0  Benchmark datasets and experiment hyperparamet...
# 1  Vowel, Spambase, Breast Cancer, and Gisette pe...
# 2  Modern tabular-baseline rows in the dataset pe...
# 3  Manuscript-ready CSV table package assembled f...
# 4  Architecture, schedule, threshold, sparsity, H...
# 5  Boundary-bin correction and representative Bre...
# 6  Explanation-form comparison and GRS rule-path ...
# 7  Paired statistics and final reproducibility in...
#
#                                       evidence_block  \
# 0  dataset dimensions plus hyperparameters read f...
# 1      ANFIS-family, SVM, and GRS-ANFIS fold metrics
# 2  RF/HGB/XGBoost/LightGBM/CatBoost/EBM fold metrics
# 3  copies only tables generated by direct experim...
# 4  GRS threshold/lambda/architecture/schedule/fir...
# 5  Q1 boundary-bin correction and BCWD case recov...
# 6  SHAP/LIME recomputation and GRS rule-path diag...
# 7  paired tests from generated fold-level results...
#
#                                     generated_output
# 0          output/reproducible_paper_tables/00_*.csv
# 1  output/reproducible_paper_tables/01_main_neuro...
# 2  output/reproducible_paper_tables/02_tabular_ba...
# 3  output/reproducible_paper_tables/manuscript_ta...
# 4          output/reproducible_paper_tables/04_*.csv
# 5  output/reproducible_paper_tables/05_boundary/*...
# 6  output/reproducible_paper_tables/06_interpreta...
# 7          output/reproducible_paper_tables/07_*.csv
