# %%
from model import *

model = GH_ANFIS(4,1)

# %%
import torch

x = torch.tensor([[1.0, 2.0, 3.0, 4.0]])
output = model(x)
print(output)
# Out:
# complement_mask: tensor([1., 1., 1., 1.])
# gate_residual_mask: tensor([[0.5000, 0.5000, 0.5000, 0.5000]], grad_fn=<ExpandBackward0>)
# tensor([[0.4955]], grad_fn=<AddBackward0>)
